# %%
import pandas as pd
import numpy as np 
import csv
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stops = r"/Users/phamthiphuongthuy/Desktop/Unimelb/Y2S1/EODP/eodp_a2/A2 datasets/stops_vista_2023_2024.csv"
trips = r"/Users/phamthiphuongthuy/Desktop/Unimelb/Y2S1/EODP/eodp_a2/A2 datasets/trips_vista_2023_2024.csv"

# %%
stops = pd.read_csv(stops, on_bad_lines='skip')
trips = pd.read_csv(trips, on_bad_lines='skip')
stops = pd.DataFrame(stops)
trips = pd.DataFrame(trips)
# Out:
# /var/folders/2f/l2t6rv7j4pjfjqq_ymr89c2r0000gn/T/ipykernel_8432/726138831.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   stops = pd.read_csv(stops, on_bad_lines='skip')
# /var/folders/2f/l2t6rv7j4pjfjqq_ymr89c2r0000gn/T/ipykernel_8432/726138831.py:2: DtypeWarning: Columns (18,19,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   trips = pd.read_csv(trips, on_bad_lines='skip')
#                   stopid         hhid          persid  stopno    travdow  \
# 0      Y24H5740102P01S01  Y24H5740102  Y24H5740102P01       1    Tuesday
# 1      Y24H5740102P01S02  Y24H5740102  Y24H5740102P01       2    Tuesday
# 2      Y24H5740102P01S03  Y24H5740102  Y24H5740102P01       3    Tuesday
# 3      Y24H5740102P01S04  Y24H5740102  Y24H5740102P01       4    Tuesday
# 4      Y24H5740102P01S05  Y24H5740102  Y24H5740102P01       5    Tuesday
# ...                  ...          ...             ...     ...        ...
# 27855  Y24H6250438P03S03  Y24H6250438  Y24H6250438P03       3  Wednesday
# 27856  Y24H6250438P03S04  Y24H6250438  Y24H6250438P03       4  Wednesday
# 27857  Y24H6250438P04S01  Y24H6250438  Y24H6250438P04       1  Wednesday
# 27858  Y24H6250438P04S02  Y24H6250438  Y24H6250438P04       2  Wednesday
# 27859  Y24H6250438P04S03  Y24H6250438  Y24H6250438P04       3  Wednesday
#
#                        origplace1                origplace2  \
# 0                   Accommodation               Survey Home
# 1                    Retail venue           Shopping Centre
# 2                   Accommodation               Survey Home
# 3                    Retail venue                  Hardware
# 4               Personal services                  Hospital
# ...                           ...                       ...
# 27855           Personal services  Hairdresser Beauty Salon
# 27856  Sport and Recreation venue        Other Indoor Sport
# 27857               Accommodation               Survey Home
# 27858          Place of education            Primary School
# 27859           Personal services  Hairdresser Beauty Salon
#
#                  origlga  starthour          origpurp1  ...  \
# 0              Casey (C)         13            At Home  ...
# 1              Casey (C)         13      Buy Something  ...
# 2              Casey (C)         16            At Home  ...
# 3          Frankston (C)         16             Social  ...
# 4          Melbourne (C)         19             Social  ...
# ...                  ...        ...                ...  ...
# 27855  Moonee Valley (C)         16  Accompany Someone  ...
# 27856  Moonee Valley (C)         18       Recreational  ...
# 27857  Moonee Valley (C)          8            At Home  ...
# 27858  Moonee Valley (C)         16          Education  ...
# 27859  Moonee Valley (C)         16  Personal Business  ...
#
#       stoppoststratweight_GROUP_4 stoppoststratweight_GROUP_5  \
# 0                     1386.611796                 1398.142956
# 1                     1386.611796                 1398.142956
# 2                     1386.611796                 1398.142956
# 3                     1386.611796                 1398.142956
# 4                     1386.611796                 1398.142956
# ...                           ...                         ...
# 27855                    0.000000                  436.929794
# 27856                    0.000000                  436.929794
# 27857                    0.000000                  791.367776
# 27858                    0.000000                  791.367776
# 27859                    0.000000                  791.367776
#
#       stoppoststratweight_GROUP_6 stoppoststratweight_GROUP_7  \
# 0                        0.000000                 1273.620375
# 1                        0.000000                 1273.620375
# 2                        0.000000                 1273.620375
# 3                        0.000000                 1273.620375
# 4                        0.000000                 1273.620375
# ...                           ...                         ...
# 27855                  463.978114                  723.599544
# 27856                  463.978114                  723.599544
# 27857                  740.607527                  778.680850
# 27858                  740.607527                  778.680850
# 27859                  740.607527                  778.680850
#
#       stoppoststratweight_GROUP_8 stoppoststratweight_GROUP_9  \
# 0                     1212.280624                 1075.466480
# 1                     1212.280624                 1075.466480
# 2                     1212.280624                 1075.466480
# 3                     1212.280624                 1075.466480
# 4                     1212.280624                 1075.466480
# ...                           ...                         ...
# 27855                  516.305744                  479.161511
# 27856                  516.305744                  479.161511
# 27857                  745.665999                  685.399032
# 27858                  745.665999                  685.399032
# 27859                  745.665999                  685.399032
#
#       stoppoststratweight_GROUP_10 homesubregion_ASGS    homeregion_ASGS  \
# 0                      1857.769283       MELB - Outer  Greater Melbourne
# 1                      1857.769283       MELB - Outer  Greater Melbourne
# 2                      1857.769283       MELB - Outer  Greater Melbourne
# 3                      1857.769283       MELB - Outer  Greater Melbourne
# 4                      1857.769283       MELB - Outer  Greater Melbourne
# ...                            ...                ...                ...
# 27855                   531.283057      MELB - Middle  Greater Melbourne
# 27856                   531.283057      MELB - Middle  Greater Melbourne
# 27857                  1192.233376      MELB - Middle  Greater Melbourne
# 27858                  1192.233376      MELB - Middle  Greater Melbourne
# 27859                  1192.233376      MELB - Middle  Greater Melbourne
#
#        dayType
# 0      Weekday
# 1      Weekday
# 2      Weekday
# 3      Weekday
# 4      Weekday
# ...        ...
# 27855  Weekday
# 27856  Weekday
# 27857  Weekday
# 27858  Weekday
# 27859  Weekday
#
# [27860 rows x 66 columns]
